# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint

r = requests.get('https://api.github.com/events')
pprint(r.text)
# Out:
# ('[{"id":"51911333376","type":"DeleteEvent","actor":{"id":21332201,"login":"zhu-weijie","display_login":"zhu-weijie","gravatar_id":"","url":"https://api.github.com/users/zhu-weijie","avatar_url":"https://avatars.githubusercontent.com/u/21332201?"},"repo":{"id":1016416329,"name":"zhu-weijie/cogni-graph","url":"https://api.github.com/repos/zhu-weijie/cogni-graph"},"payload":{"ref":"feat/agent-orchestrator","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2025-07-10T06:45:47Z"},{"id":"51911333329","type":"PushEvent","actor":{"id":192837471,"login":"Hannahejacruw3","display_login":"Hannahejacruw3","gravatar_id":"","url":"https://api.github.com/users/Hannahejacruw3","avatar_url":"https://avatars.githubusercontent.com/u/192837471?"},"repo":{"id":910593852,"name":"Hannahejacruw3/DeFiSecurityAuditor","url":"https://api.github.com/repos/Hannahejacruw3/DeFiSecurityAuditor"},"payload":{"repository_id":910593852,"push_id":25406799117,"size":1,"distinct_size":1,"ref":"refs/he
# ...
